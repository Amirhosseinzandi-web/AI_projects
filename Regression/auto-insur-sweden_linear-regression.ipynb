# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../datasets/AutoInsurSweden.csv")
df
# Out:
#       X      Y
# 0   108  392.5
# 1    19   46.2
# 2    13   15.7
# 3   124  422.2
# 4    40  119.4
# ..  ...    ...
# 58    9   87.4
# 59   31  209.8
# 60   14   95.5
# 61   53  244.6
# 62   26  187.5
#
# [63 rows x 2 columns]

# %%
train_x = df[["X"]].values
train_y = df[["Y"]].values
df["X"]
# Out:
# 0     108
# 1      19
# 2      13
# 3     124
# 4      40
#      ...
# 58      9
# 59     31
# 60     14
# 61     53
# 62     26
# Name: X, Length: 63, dtype: int64

# %%
plt.scatter(train_x, train_y , marker=".")

# %%
model = LinearRegression()

# %%
model.fit(train_x , train_y);

# %%
print(f"model coef is ==> {model.coef_}")
print(f"model intercept is ===> {model.intercept_}")
# Out:
# model coef is ==> [[3.41382356]]
# model intercept is ===> [19.99448576]

# %%
model.score(train_x , train_y)
# Out:
# 0.8333466719794502

# %%
y_hat = model.predict(train_x)

plt.scatter(train_x, train_y , marker=".")
plt.plot(train_x , y_hat , "r-")
